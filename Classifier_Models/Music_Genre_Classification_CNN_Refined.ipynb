# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization, Dropout, Flatten, Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
import matplotlib.pyplot as plt
import seaborn as sns

# Load GTZAN Features CSV
df = pd.read_csv("features_3_sec.csv")

# Display the first few rows of the dataset
df.head()
# Out:
#             filename  length  chroma_stft_mean  chroma_stft_var  rms_mean  \
# 0  blues.00000.0.wav   66149          0.335406         0.091048  0.130405
# 1  blues.00000.1.wav   66149          0.343065         0.086147  0.112699
# 2  blues.00000.2.wav   66149          0.346815         0.092243  0.132003
# 3  blues.00000.3.wav   66149          0.363639         0.086856  0.132565
# 4  blues.00000.4.wav   66149          0.335579         0.088129  0.143289
#
#     rms_var  spectral_centroid_mean  spectral_centroid_var  \
# 0  0.003521             1773.065032          167541.630869
# 1  0.001450             1816.693777           90525.690866
# 2  0.004620             1788.539719          111407.437613
# 3  0.002448             1655.289045          111952.284517
# 4  0.001701             1630.656199           79667.267654
#
#    spectral_bandwidth_mean  spectral_bandwidth_var  ...  mfcc16_var  \
# 0              1972.744388           117335.771563  ...   39.687145
# 1              2010.051501            65671.875673  ...   64.748276
# 2              2084.565132            75124.921716  ...   67.336563
# 3              1960.039988            82913.639269  ...   47.739452
# 4              1948.503884            60204.020268  ...   30.336359
#
#    mfcc17_mean  mfcc17_var  mfcc18_mean  mfcc18_var  mfcc19_mean  mfcc19_var  \
# 0    -3.241280   36.488243     0.722209   38.099152    -5.050335   33.618073
# 1    -6.055294   40.677654     0.159015   51.264091    -2.837699   97.030830
# 2    -1.768610   28.348579     2.378768   45.717648    -1.938424   53.050835
# 3    -3.841155   28.337118     1.218588   34.770935    -3.580352   50.836224
# 4     0.664582   45.880913     1.689446   51.363583    -3.392489   26.738789
#
#    mfcc20_mean  mfcc20_var  label
# 0    -0.243027   43.771767  blues
# 1     5.784063   59.943081  blues
# 2     2.517375   33.105122  blues
# 3     3.630866   32.023678  blues
# 4     0.536961   29.146694  blues
#
# [5 rows x 60 columns]

# %%
#to know the name of the columns
df.columns
# Out:
# Index(['filename', 'length', 'chroma_stft_mean', 'chroma_stft_var', 'rms_mean',
#        'rms_var', 'spectral_centroid_mean', 'spectral_centroid_var',
#        'spectral_bandwidth_mean', 'spectral_bandwidth_var', 'rolloff_mean',
#        'rolloff_var', 'zero_crossing_rate_mean', 'zero_crossing_rate_var',
#        'harmony_mean', 'harmony_var', 'perceptr_mean', 'perceptr_var', 'tempo',
#        'mfcc1_mean', 'mfcc1_var', 'mfcc2_mean', 'mfcc2_var', 'mfcc3_mean',
#        'mfcc3_var', 'mfcc4_mean', 'mfcc4_var', 'mfcc5_mean', 'mfcc5_var',
#        'mfcc6_mean', 'mfcc6_var', 'mfcc7_mean', 'mfcc7_var', 'mfcc8_mean',
#        'mfcc8_var', 'mfcc9_mean', 'mfcc9_var', 'mfcc10_mean', 'mfcc10_var',
#        'mfcc11_mean', 'mfcc11_var', 'mfcc12_mean', 'mfcc12_var', 'mfcc13_mean',
#        'mfcc13_var', 'mfcc14_mean', 'mfcc14_var', 'mfcc15_mean', 'mfcc15_var',
#        'mfcc16_mean', 'mfcc16_var', 'mfcc17_mean', 'mfcc17_var', 'mfcc18_mean',
#        'mfcc18_var', 'mfcc19_mean', 'mfcc19_var', 'mfcc20_mean', 'mfcc20_var',
#        'label'],
#       dtype='object')

# %%
# Feature Selection
features = [
    "chroma_stft_mean", "chroma_stft_var",
    "spectral_centroid_mean", "spectral_centroid_var",
    "spectral_bandwidth_mean", "spectral_bandwidth_var",
    "rolloff_mean", "rolloff_var",
    "zero_crossing_rate_mean", "zero_crossing_rate_var",
    "harmony_mean", "harmony_var",
    "perceptr_mean", "perceptr_var",
    "tempo"
]

# Add MFCC Means & Variances
mfcc_features = [f"mfcc{i}_mean" for i in range(1, 21)] + [f"mfcc{i}_var" for i in range(1, 21)]
features.extend(mfcc_features)

# Extract Features and Labels
X = df[features].values
y = df['label']

# Encode Labels
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# %%
# Train-Test Split (80-20 Split)
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded)

# Normalize Features for SVM
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Ensure proper reshaping for CNN input
X_train = X_train.reshape(X_train.shape[0], 55, 1, 1)  # Adjust as per actual feature size
X_test = X_test.reshape(X_test.shape[0], 55, 1, 1)

# Training CNN Model
model = Sequential([
    Conv2D(32, kernel_size=(3, 1), activation='relu', input_shape=(55, 1, 1)),  # Fixed input shape
    MaxPooling2D(pool_size=(2, 1)),
    Dropout(0.3),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(len(np.unique(y_encoded)), activation='softmax')  # Fixed to use `y_encoded`
])

# Compile the model
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Model Summary
model.summary()

# Define EarlyStopping
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

# Train the model with EarlyStopping
history = model.fit(
    X_train, y_train,
    epochs=100,
    batch_size=32,
    validation_data=(X_test, y_test),
    callbacks=[early_stop]    # Include the callback here
)

# Evaluate on the test set
test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 53, 1, 32)      │           128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 26, 1, 32)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 26, 1, 32)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 832)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       106,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 108,042 (422.04 KB)
#  Trainable params: 108,042 (422.04 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.3939 - loss: 1.7103 - val_accuracy: 0.6151 - val_loss: 1.1148
# Epoch 2/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6030 - loss: 1.1445 - val_accuracy: 0.6897 - val_loss: 0.9218
# Epoch 3/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6624 - loss: 0.9784 - val_accuracy: 0.7272 - val_loss: 0.8325
# Epoch 4/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6936 - loss: 0.8942 - val_accuracy: 0.7332 - val_loss: 0.7930
# Epoch 5/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7052 - loss: 0.8463 - val_accuracy: 0.7497 - val_loss: 0.7316
# Epoch 6/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7258 - loss: 0.7770 - val_accuracy: 0.7598 - val_loss: 0.7150
# Epoch 7/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7536 - loss: 0.7349 - val_accuracy: 0.7778 - val_loss: 0.6681
# Epoch 8/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7545 - loss: 0.7152 - val_accuracy: 0.7818 - val_loss: 0.6429
# Epoch 9/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7666 - loss: 0.6711 - val_accuracy: 0.7903 - val_loss: 0.6119
# Epoch 10/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7738 - loss: 0.6479 - val_accuracy: 0.7923 - val_loss: 0.6021
# Epoch 11/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7823 - loss: 0.6170 - val_accuracy: 0.8073 - val_loss: 0.5871
# Epoch 12/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7955 - loss: 0.5823 - val_accuracy: 0.8103 - val_loss: 0.5575
# Epoch 13/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8080 - loss: 0.5606 - val_accuracy: 0.8208 - val_loss: 0.5481
# Epoch 14/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8116 - loss: 0.5538 - val_accuracy: 0.8233 - val_loss: 0.5485
# Epoch 15/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8279 - loss: 0.5086 - val_accuracy: 0.8268 - val_loss: 0.5362
# Epoch 16/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8285 - loss: 0.4965 - val_accuracy: 0.8373 - val_loss: 0.5167
# Epoch 17/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8284 - loss: 0.5048 - val_accuracy: 0.8303 - val_loss: 0.5172
# Epoch 18/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8372 - loss: 0.4721 - val_accuracy: 0.8438 - val_loss: 0.4982
# Epoch 19/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8410 - loss: 0.4572 - val_accuracy: 0.8378 - val_loss: 0.4894
# Epoch 20/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8421 - loss: 0.4508 - val_accuracy: 0.8383 - val_loss: 0.4898
# Epoch 21/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8492 - loss: 0.4291 - val_accuracy: 0.8433 - val_loss: 0.4844
# Epoch 22/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8415 - loss: 0.4402 - val_accuracy: 0.8498 - val_loss: 0.4868
# Epoch 23/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8581 - loss: 0.4091 - val_accuracy: 0.8363 - val_loss: 0.4734
# Epoch 24/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8560 - loss: 0.4067 - val_accuracy: 0.8478 - val_loss: 0.4810
# Epoch 25/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8641 - loss: 0.3914 - val_accuracy: 0.8559 - val_loss: 0.4608
# Epoch 26/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8615 - loss: 0.3944 - val_accuracy: 0.8584 - val_loss: 0.4521
# Epoch 27/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8629 - loss: 0.3924 - val_accuracy: 0.8589 - val_loss: 0.4654
# Epoch 28/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8655 - loss: 0.3834 - val_accuracy: 0.8498 - val_loss: 0.4706
# Epoch 29/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8784 - loss: 0.3666 - val_accuracy: 0.8589 - val_loss: 0.4548
# Epoch 30/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8653 - loss: 0.3691 - val_accuracy: 0.8544 - val_loss: 0.4462
# Epoch 31/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8730 - loss: 0.3578 - val_accuracy: 0.8604 - val_loss: 0.4775
# Epoch 32/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8821 - loss: 0.3469 - val_accuracy: 0.8649 - val_loss: 0.4504
# Epoch 33/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8823 - loss: 0.3344 - val_accuracy: 0.8714 - val_loss: 0.4358
# Epoch 34/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8781 - loss: 0.3334 - val_accuracy: 0.8599 - val_loss: 0.4489
# Epoch 35/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8816 - loss: 0.3304 - val_accuracy: 0.8599 - val_loss: 0.4405
# Epoch 36/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8754 - loss: 0.3366 - val_accuracy: 0.8639 - val_loss: 0.4320
# Epoch 37/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8785 - loss: 0.3365 - val_accuracy: 0.8604 - val_loss: 0.4516
# Epoch 38/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8844 - loss: 0.3390 - val_accuracy: 0.8614 - val_loss: 0.4411
# Epoch 39/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8987 - loss: 0.3038 - val_accuracy: 0.8639 - val_loss: 0.4453
# Epoch 40/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8850 - loss: 0.3344 - val_accuracy: 0.8689 - val_loss: 0.4340
# Epoch 41/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8967 - loss: 0.3010 - val_accuracy: 0.8689 - val_loss: 0.4264
# Epoch 42/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8898 - loss: 0.3169 - val_accuracy: 0.8679 - val_loss: 0.4464
# Epoch 43/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8952 - loss: 0.3081 - val_accuracy: 0.8644 - val_loss: 0.4263
# Epoch 44/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8912 - loss: 0.3040 - val_accuracy: 0.8724 - val_loss: 0.4361
# Epoch 45/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8889 - loss: 0.3024 - val_accuracy: 0.8644 - val_loss: 0.4430
# Epoch 46/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8890 - loss: 0.3082 - val_accuracy: 0.8719 - val_loss: 0.4319
# Epoch 47/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8953 - loss: 0.2909 - val_accuracy: 0.8639 - val_loss: 0.4469
# Epoch 48/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8982 - loss: 0.2910 - val_accuracy: 0.8684 - val_loss: 0.4346
# Test Accuracy: 86.44%

# %%
# Predict for a single sample
# Select a sample from the test set
sample_num = 10
sample = X_test[sample_num].reshape(1, 55, 1, 1)  # Reshape for prediction

# Predict the genre
prediction = np.argmax(model.predict(sample))
predicted_genre = label_encoder.inverse_transform([prediction])

# Print the result
print(f"Predicted Genre: {predicted_genre[0]}")
print(f"Actual Genre: {label_encoder.inverse_transform([y_test[sample_num]])}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step
# Predicted Genre: pop
# Actual Genre: ['pop']
